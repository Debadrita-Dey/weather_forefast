# %%
import pandas as pd
import numpy as np
file=r"C:\Users\DELL\Desktop\ml\data analysis2\weather_dataset_stage1.xlsx"
df=pd.read_excel(file)
df.head()
# Out:
#           Date  Temperature  Average humidity (%  Average dewpoint (°F  \
# 0   2022-01-01         37.8               '35.0'                '12.7'
# 1  2022-01-02'       '43.2'               '32.0'                '14.7'
# 2  2022-01-03'       '25.7'               '60.0'                '12.7'
# 3  2022-01-04'        '9.3'               '67.0'                 '0.1'
# 4  2022-01-05'       '23.5'               '30.0'                '-5.3'
#
#    Average barometer (in  Average windspeed (mph  Average gustspeed (mph  \
# 0                 '29.7'                  '26.4'                  '36.8'
# 1                 '29.5'                  '12.8'                  '18.0'
# 2                 '29.7'                   '8.3'                  '12.2'
# 3                 '30.4'                   '2.9'                   '4.5'
# 4                 '29.9'                  '16.7'                  '23.1'
#
#    Average direction (°deg  Rainfall for month (in Rainfall for year (in  ...  \
# ...

# %%
df.isnull().sum()
# Out:
# Date                        0
#  Temperature                0
#  Average humidity (%        0
#  Average dewpoint (°F       0
#  Average barometer (in      0
#  Average windspeed (mph     0
#  Average gustspeed (mph     0
#  Average direction (°deg    0
#  Rainfall for month (in     0
# Rainfall for year (in       0
#  Maximum rain per minute    0
#  Maximum temperature (°F    0
#  Minimum temperature (°F    0
#  Maximum humidity (%        0
#  Minimum humidity (%        0
#  Maximum pressure           0
#  Minimum pressure           0
#  Maximum windspeed (mph     0
#  Maximum gust speed (mph    0
#  Maximum heat index (°F     0
# Date1                       0
#  Month                      0
#  diff_pressure              0
# dtype: int64

# %%
df.columns=df.columns.str.lower()
df.columns
# Out:
# Index(['date', ' temperature', ' average humidity (%', ' average dewpoint (°f',
#        ' average barometer (in', ' average windspeed (mph',
#        ' average gustspeed (mph', ' average direction (°deg',
#        ' rainfall for month (in', 'rainfall for year (in',
#        ' maximum rain per minute', ' maximum temperature (°f',
#        ' minimum temperature (°f', ' maximum humidity (%',
#        ' minimum humidity (%', ' maximum pressure', ' minimum pressure',
#        ' maximum windspeed (mph', ' maximum gust speed (mph',
#        ' maximum heat index (°f', 'date1', ' month', ' diff_pressure'],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()
df.columns
# Out:
# Index(['date', 'temperature', 'average humidity (%', 'average dewpoint (°f',
#        'average barometer (in', 'average windspeed (mph',
#        'average gustspeed (mph', 'average direction (°deg',
#        'rainfall for month (in', 'rainfall for year (in',
#        'maximum rain per minute', 'maximum temperature (°f',
#        'minimum temperature (°f', 'maximum humidity (%', 'minimum humidity (%',
#        'maximum pressure', 'minimum pressure', 'maximum windspeed (mph',
#        'maximum gust speed (mph', 'maximum heat index (°f', 'date1', 'month',
#        'diff_pressure'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(' ','_')
df.columns
# Out:
# Index(['date', 'temperature', 'average_humidity_(%', 'average_dewpoint_(°f',
#        'average_barometer_(in', 'average_windspeed_(mph',
#        'average_gustspeed_(mph', 'average_direction_(°deg',
#        'rainfall_for_month_(in', 'rainfall_for_year_(in',
#        'maximum_rain_per_minute', 'maximum_temperature_(°f',
#        'minimum_temperature_(°f', 'maximum_humidity_(%', 'minimum_humidity_(%',
#        'maximum_pressure', 'minimum_pressure', 'maximum_windspeed_(mph',
#        'maximum_gust_speed_(mph', 'maximum_heat_index_(°f', 'date1', 'month',
#        'diff_pressure'],
#       dtype='object')

# %%
df.dtypes
# Out:
# date                       object
# temperature                object
# average_humidity_(%        object
# average_dewpoint_(°f       object
# average_barometer_(in      object
# average_windspeed_(mph     object
# average_gustspeed_(mph     object
# average_direction_(°deg    object
# rainfall_for_month_(in     object
# rainfall_for_year_(in      object
# maximum_rain_per_minute    object
# maximum_temperature_(°f    object
# minimum_temperature_(°f    object
# maximum_humidity_(%        object
# minimum_humidity_(%        object
# maximum_pressure           object
# minimum_pressure           object
# maximum_windspeed_(mph     object
# maximum_gust_speed_(mph    object
# maximum_heat_index_(°f     object
# date1                      object
# month                      object
# diff_pressure              object
# dtype: object

# %%
df.describe()
# Out:
#                date temperature average_humidity_(% average_dewpoint_(°f  \
# count          3903        3903                3903                 3903
# unique         3902         657                  86                  638
# top     2033-07-28'      '46.9'              '51.0'               '15.7'
# freq              2          17                  99                   18
#
#        average_barometer_(in average_windspeed_(mph average_gustspeed_(mph  \
# count                   3903                   3903                   3903
# unique                    22                    206                    332
# top                   '29.8'                  '2.3'                  '3.9'
# freq                     715                     85                     60
#
#        average_direction_(°deg rainfall_for_month_(in rainfall_for_year_(in  \
# count                     3903                   3903                  3903
# ...

# %%
df.head()
# Out:
#           date temperature average_humidity_(% average_dewpoint_(°f  \
# 0   2022-01-01        37.8              '35.0'               '12.7'
# 1  2022-01-02'      '43.2'              '32.0'               '14.7'
# 2  2022-01-03'      '25.7'              '60.0'               '12.7'
# 3  2022-01-04'       '9.3'              '67.0'                '0.1'
# 4  2022-01-05'      '23.5'              '30.0'               '-5.3'
#
#   average_barometer_(in average_windspeed_(mph average_gustspeed_(mph  \
# 0                '29.7'                 '26.4'                 '36.8'
# 1                '29.5'                 '12.8'                 '18.0'
# 2                '29.7'                  '8.3'                 '12.2'
# 3                '30.4'                  '2.9'                  '4.5'
# 4                '29.9'                 '16.7'                 '23.1'
#
#   average_direction_(°deg rainfall_for_month_(in rainfall_for_year_(in  ...  \
# ...

# %%
df.drop(columns=['date1'],axis=1,inplace=True)

# %%
df.head()
# Out:
#           date temperature average_humidity_(% average_dewpoint_(°f  \
# 0   2022-01-01        37.8              '35.0'               '12.7'
# 1  2022-01-02'      '43.2'              '32.0'               '14.7'
# 2  2022-01-03'      '25.7'              '60.0'               '12.7'
# 3  2022-01-04'       '9.3'              '67.0'                '0.1'
# 4  2022-01-05'      '23.5'              '30.0'               '-5.3'
#
#   average_barometer_(in average_windspeed_(mph average_gustspeed_(mph  \
# 0                '29.7'                 '26.4'                 '36.8'
# 1                '29.5'                 '12.8'                 '18.0'
# 2                '29.7'                  '8.3'                 '12.2'
# 3                '30.4'                  '2.9'                  '4.5'
# 4                '29.9'                 '16.7'                 '23.1'
#
#   average_direction_(°deg rainfall_for_month_(in rainfall_for_year_(in  ...  \
# ...

# %%
df=df.applymap(lambda x:x.replace("'",'')if isinstance(x, str) else x)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_5636\1464963266.py:1: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df=df.applymap(lambda x:x.replace("'",'')if isinstance(x, str) else x)

# %%
df.head()
# Out:
#          date temperature average_humidity_(% average_dewpoint_(°f  \
# 0  2022-01-01        37.8                35.0                 12.7
# 1  2022-01-02        43.2                32.0                 14.7
# 2  2022-01-03        25.7                60.0                 12.7
# 3  2022-01-04         9.3                67.0                  0.1
# 4  2022-01-05        23.5                30.0                 -5.3
#
#   average_barometer_(in average_windspeed_(mph average_gustspeed_(mph  \
# 0                  29.7                   26.4                   36.8
# 1                  29.5                   12.8                   18.0
# 2                  29.7                    8.3                   12.2
# 3                  30.4                    2.9                    4.5
# 4                  29.9                   16.7                   23.1
#
#   average_direction_(°deg rainfall_for_month_(in rainfall_for_year_(in  ...  \
# ...

# %%
df.drop_duplicates(inplace=True)
df.shape
# Out:
# (3902, 22)

# %%
invalid_dates = df[pd.to_datetime(df['date'], errors='coerce').notna()]
print(invalid_dates)
# Out:
#             date temperature average_humidity_(% average_dewpoint_(°f  \
# 0     2022-01-01        37.8                35.0                 12.7
# 1     2022-01-02        43.2                32.0                 14.7
# 2     2022-01-03        25.7                60.0                 12.7
# 3     2022-01-04         9.3                67.0                  0.1
# 4     2022-01-05        23.5                30.0                 -5.3
# ...          ...         ...                 ...                  ...
# 3897  2033-07-24        64.1                62.0                 49.8
# 3898  2033-07-25        62.8                60.0                 48.1
# 3899  2033-07-26        60.6                68.0                 48.9
# 3900  2033-07-27        61.7                64.0                 47.4
# 3901  2033-07-28        60.5                61.0                 45.3
#
#      average_barometer_(in average_windspeed_(mph average_gustspeed_(mph  \
# ...

# %%
df['date'] = pd.to_datetime(df['date'], errors='coerce') 
df = df.dropna(subset=['date'])

# %%
df.shape
# Out:
# (3900, 22)

# %%
df.to_csv(r"C:\Users\DELL\Desktop\ml\cleaned.csv",index=False)
print("done")
# Out:
# done
